# %%
import pandas as pd
import random
import matplotlib.pylab as plt
import matplotlib.patches as mpatches
import math
import statistics as stat
from scipy.stats import norm
import numpy as np
import pprint

# %%
basic= {'Elye Wahi': 'FW',
 'Iago Aspas': 'FW',
 'Jonathan David': 'FW',
 'Jude Bellingham': 'MF',
 'Loïs Openda': 'FW',
 'Ludovic Blas': 'MF,FW',
 'Luis Alberto': 'MF',
 'Rafael Leão': 'FW,MF',
 'Rémy Cabella': 'MF,FW',
 'Seko Fofana': 'MF',
 'Sergi Darder': 'MF'}

# %%
shooting = {'Alex Baena': 'MF,FW',
 'Amine Gouiri': 'FW,MF',
 'Arthur': 'RB',
 'Folarin Balogun': 'FW',
 'Habib Diallo': 'FW',
 'Harvey Barnes': 'FW,MF',
 'Iago Aspas': 'FW',
 'Jonathan David': 'FW',
 'Julián Álvarez': 'FW,MF',
 'Ludovic Blas': 'MF,FW',
 'Marvin Ducksch': 'FW',
 'Miguel Almirón': 'FW',
 'Moussa Diaby': 'FW,MF',
 'Niclas Füllkrug': 'FW',
 'Sheraldo Becker': 'FW',
 'Thijs Dallinga': 'FW',
 'Valentín Castellanos': 'FW',
 'Zakaria Aboukhlal': 'FW,MF'}

# %%
passing ={'Adam Webster': 'DF',
 'Andre-Frank Zambo Anguissa': 'MF',
 'Arthur Theate': 'DF',
 'Ashley Young': 'DF',
 'Dan-Axel Zagadou': 'DF',
 'Daniel Vivian': 'DF',
 'Davide Zappacosta': 'DF',
 'Duván Zapata': 'FW',
 'Edon Zhegrova': 'FW,MF',
 'Fikayo Tomori': 'DF',
 'Filip Đuričić': 'MF,FW',
 'Florian Wirtz': 'FW,MF',
 'Harry Wilson': 'FW',
 'Harry Winks': 'MF',
 'Igor Zubeldia': 'DF',
 'Jawad El Yamiq': 'DF',
 'Joe Willock': 'MF',
 'Joe Worrall': 'DF',
 'Jordan Zemura': 'DF',
 'Julian Weigl': 'MF',
 'Kevin Vogt': 'DF',
 'Leny Yoro': 'CB',
 'Marius Wolf': 'DF',
 'Martín Zubimendi': 'MF',
 'Mateusz Wieteska': 'CB',
 'Mattia Zaccagni': 'FW',
 'Maximilian Wöber': 'DF',
 'Maya Yoshida': 'DF',
 'Mehdi Zeffane': 'DF,MF',
 'Micky van de Ven': 'DF',
 'Mohamed Youssouf': 'DF',
 'Nicola Zalewski': 'DF',
 'Przemysław Wiśniewski': 'DF',
 'Robin Zentner': 'GK',
 'Rodrigo Zalazar': 'MF,FW',
 'Ryan Yates': 'MF',
 'Timothy Weah': 'DF,FW',
 'Vitinha': 'CF',
 'Walace': 'MF',
 'Willian': 'FW',
 'Xeka': 'MF'}

# %%
miscellaneous={'Axel Disasi': 'DF',
 'Benjamin André': 'MF',
 'Chancel Mbemba': 'DF',
 'Dante': 'DF',
 'Ellyes Skhiri': 'MF',
 'Emmanuel Agbadou': 'DF',
 'Fabiano Parisi': 'DF',
 'Isak Hien': 'CB',
 'Jefferson Lerma': 'MF',
 'Joachim Andersen': 'DF',
 'Jonas Hector': 'DF',
 'Kevin Danso': 'DF',
 'Lewis Dunk': 'DF',
 'Max Kilman': 'DF',
 'Mikkel Desler': 'DF',
 'Moisés Caicedo': 'MF',
 'Nabil Bentaleb': 'MF',
 'Pierre Højbjerg': 'MF',
 'Pierre Lees-Melou': 'MF',
 'Tyrone Mings': 'DF',
 'Waldemar Anton': 'DF',
 'Wataru Endo': 'MF',
 'Yunis Abdelhamid': 'DF'}

# %%
defensive = {'Alexis Blin': 'MF',
 'Alfonso Espino': 'DF',
 'Andrei Girotto': 'DF,MF',
 'Anthony Losilla': 'MF',
 'Benjamin André': 'MF',
 'Bryan Cristante': 'MF,DF',
 'Enzo Le Fée': 'MF',
 'Felipe Anderson': 'FW',
 'Fran Garcia': 'DF',
 'Guido Rodríguez': 'MF',
 'Haris Belkebla': 'MF',
 'Idrissa Gana Gueye': 'MF',
 'Javi Galán': 'DF',
 'Jonas Hector': 'DF',
 'João Palhinha': 'MF',
 'Jude Bellingham': 'MF',
 'Laurent Abergel': 'MF',
 'Maxence Caqueret': 'MF',
 'Melvin Bard': 'DF',
 'Mohamed Camara': 'MF',
 'Moisés Caicedo': 'MF',
 'Neto Borges': 'DF',
 'Nicolás Tagliafico': 'DF',
 'Pierre Lees-Melou': 'MF',
 'Rúben Neves': 'MF',
 'Stijn Spierings': 'MF',
 'Timothy Castagne': 'DF',
 'Tom Krauß': 'MF',
 'Tyler Adams': 'MF',
 'Valentin Gendrey': 'DF',
 'Valentin Rongier': 'MF',
 'Xavier Chavalerin': 'MF',
 'Yohann Magnin': 'MF',
 'Youssouf Fofana': 'MF',
 'Yunis Abdelhamid': 'DF'}

# %%
gsc={'Aleksandr Golovin': 'MF,FW',
 'Dominik Szoboszlai': 'MF,FW',
 'Eberechi Eze': 'MF,FW',
 'Harry Kane': 'FW',
 'Jarrod Bowen': 'FW,MF',
 'Jeremie Frimpong': 'DF,MF',
 'Jude Bellingham': 'MF',
 'Junya Ito': 'FW',
 'Khvicha Kvaratskhelia': 'FW',
 'Lee Kang-in': 'MF,FW',
 'Ludovic Blas': 'MF,FW',
 'Michael Olise': 'FW,MF',
 'Moussa Diaby': 'FW,MF',
 'Rémy Cabella': 'MF,FW',
 'Solly March': 'FW,DF',
 'Son Heung-min': 'MF,FW'}

# %%
possesion = {'Alejandro Balde': 'DF',
 'Carlos': 'DF',
 'Enzo Le Fée': 'MF',
 'Felipe Anderson': 'FW',
 'Giovanni Di Lorenzo': 'DF',
 'Javi Galán': 'DF',
 'Jonathan Bamba': 'FW',
 'Jude Bellingham': 'MF',
 'Ludovic Blas': 'MF,FW',
 'Luis Alberto': 'MF',
 'Maxence Caqueret': 'MF',
 'Pascal Groß': 'MF,DF',
 'Pervis Estupiñán': 'DF',
 'Raphaël Guerreiro': 'DF,MF',
 'Rémy Cabella': 'MF,FW',
 'Seko Fofana': 'MF',
 'Valentin Rongier': 'MF'}

# %%
pass_types={'Angel Gomes': 'MF',
 'Antonio Candreva': 'MF,DF',
 'Benjamin Bourigeaud': 'MF,FW',
 'Branco van den Boomen': 'MF',
 'Daniel Parejo': 'MF',
 'Jude Bellingham': 'MF',
 'Khvicha Kvaratskhelia': 'FW',
 'Luis Alberto': 'MF',
 'Moisés Caicedo': 'MF',
 'Nabil Bentaleb': 'MF',
 'Pascal Groß': 'MF,DF',
 'Pierre Højbjerg': 'MF',
 'Pierre Lees-Melou': 'MF',
 'Seko Fofana': 'MF',
 'Sergi Darder': 'MF'}

# %%
total = {}
dictionnaires = [basic, shooting, passing, miscellaneous, defensive, gsc, possesion, pass_types]
for dictionnaire in dictionnaires:
    for key in dictionnaire:
        if key in total:
            total[key] += 1
        else:
            total[key] = 1
total_sorted = {k: v for k, v in sorted(total.items(), key=lambda item: item[1], reverse=True)}
for key, value in total_sorted.items():
    print(f"{key}: {value}")
# Out:
# Jude Bellingham: 5
# Ludovic Blas: 4
# Luis Alberto: 3
# Rémy Cabella: 3
# Seko Fofana: 3
# Moisés Caicedo: 3
# Pierre Lees-Melou: 3
# Iago Aspas: 2
# Jonathan David: 2
# Sergi Darder: 2
# Moussa Diaby: 2
# Benjamin André: 2
# Jonas Hector: 2
# Nabil Bentaleb: 2
# Pierre Højbjerg: 2
# Yunis Abdelhamid: 2
# Enzo Le Fée: 2
# Felipe Anderson: 2
# Javi Galán: 2
# Maxence Caqueret: 2
# Valentin Rongier: 2
# Khvicha Kvaratskhelia: 2
# Pascal Groß: 2
# Elye Wahi: 1
# Loïs Openda: 1
# Rafael Leão: 1
# Alex Baena: 1
# Amine Gouiri: 1
# Arthur: 1
# Folarin Balogun: 1
# Habib Diallo: 1
# Harvey Barnes: 1
# Julián Álvarez: 1
# Marvin Ducksch: 1
# Miguel Almirón: 1
# Niclas Füllkrug: 1
# Sheraldo Becker: 1
# Thijs Dallinga: 1
# Valentín Castellanos: 1
# Zakaria Aboukhlal: 1
# Adam Webster: 1
# Andre-Frank Zambo Anguissa: 1
# Arthur Theate: 1
# Ashley Young: 1
# Dan-Axel Zagadou: 1
# Daniel Vivian: 1
# Davide Zappacosta: 1
# Duván Zapata: 1
# Edon Zhegrova: 1
# Fikayo Tomori: 1
# Filip Đuričić: 1
# ...

# %%
DF = {}
dictionnaires = [basic, shooting, passing, miscellaneous, defensive, gsc, possesion, pass_types]
for dictionnaire in dictionnaires:
    for key1,value1 in dictionnaire.items():
      if value1 == "DF" :
        DF[key1]=value1
for kkey, vvalue in DF.items():
    print(f"{kkey}: {vvalue}")
# Out:
# Adam Webster: DF
# Arthur Theate: DF
# Ashley Young: DF
# Dan-Axel Zagadou: DF
# Daniel Vivian: DF
# Davide Zappacosta: DF
# Fikayo Tomori: DF
# Igor Zubeldia: DF
# Jawad El Yamiq: DF
# Joe Worrall: DF
# Jordan Zemura: DF
# Kevin Vogt: DF
# Marius Wolf: DF
# Maximilian Wöber: DF
# Maya Yoshida: DF
# Micky van de Ven: DF
# Mohamed Youssouf: DF
# Nicola Zalewski: DF
# Przemysław Wiśniewski: DF
# Axel Disasi: DF
# Chancel Mbemba: DF
# Dante: DF
# Emmanuel Agbadou: DF
# Fabiano Parisi: DF
# Joachim Andersen: DF
# Jonas Hector: DF
# Kevin Danso: DF
# Lewis Dunk: DF
# Max Kilman: DF
# Mikkel Desler: DF
# Tyrone Mings: DF
# Waldemar Anton: DF
# Yunis Abdelhamid: DF
# Alfonso Espino: DF
# Fran Garcia: DF
# Javi Galán: DF
# Melvin Bard: DF
# Neto Borges: DF
# Nicolás Tagliafico: DF
# Timothy Castagne: DF
# Valentin Gendrey: DF
# Alejandro Balde: DF
# Carlos: DF
# Giovanni Di Lorenzo: DF
# Pervis Estupiñán: DF

# %%
MF = {}
dictionnaires = [basic, shooting, passing, miscellaneous, defensive, gsc, possesion, pass_types]
for dictionnaire in dictionnaires:
    for key2,value2 in dictionnaire.items():
      if value2 == "MF" :
        MF[key2]=value2
for kkkey, vvvalue in MF.items():
    print(f"{kkkey}: {vvvalue}")
# Out:
# Jude Bellingham: MF
# Luis Alberto: MF
# Seko Fofana: MF
# Sergi Darder: MF
# Andre-Frank Zambo Anguissa: MF
# Harry Winks: MF
# Joe Willock: MF
# Julian Weigl: MF
# Martín Zubimendi: MF
# Ryan Yates: MF
# Walace: MF
# Xeka: MF
# Benjamin André: MF
# Ellyes Skhiri: MF
# Jefferson Lerma: MF
# Moisés Caicedo: MF
# Nabil Bentaleb: MF
# Pierre Højbjerg: MF
# Pierre Lees-Melou: MF
# Wataru Endo: MF
# Alexis Blin: MF
# Anthony Losilla: MF
# Enzo Le Fée: MF
# Guido Rodríguez: MF
# Haris Belkebla: MF
# Idrissa Gana Gueye: MF
# João Palhinha: MF
# Laurent Abergel: MF
# Maxence Caqueret: MF
# Mohamed Camara: MF
# Rúben Neves: MF
# Stijn Spierings: MF
# Tom Krauß: MF
# Tyler Adams: MF
# Valentin Rongier: MF
# Xavier Chavalerin: MF
# Yohann Magnin: MF
# Youssouf Fofana: MF
# Angel Gomes: MF
# Branco van den Boomen: MF
# Daniel Parejo: MF

# %%
MFFW = {}
dictionnaires = [basic, shooting, passing, miscellaneous, defensive, gsc, possesion, pass_types]
for dictionnaire in dictionnaires:
    for key3,value3 in dictionnaire.items():
      if value3 == "MF,FW" :
        MFFW[key3]=value3
for kkkkey, vvvvalue in MFFW.items():
    print(f"{kkkkey}: {vvvvalue}")
# Out:
# Ludovic Blas: MF,FW
# Rémy Cabella: MF,FW
# Alex Baena: MF,FW
# Filip Đuričić: MF,FW
# Rodrigo Zalazar: MF,FW
# Aleksandr Golovin: MF,FW
# Dominik Szoboszlai: MF,FW
# Eberechi Eze: MF,FW
# Lee Kang-in: MF,FW
# Son Heung-min: MF,FW
# Benjamin Bourigeaud: MF,FW

# %%
FW = {}
dictionnaires = [basic, shooting, passing, miscellaneous, defensive, gsc, possesion, pass_types]
for dictionnaire in dictionnaires:
    for key4,value4 in dictionnaire.items():
      if value4 == "FW" :
        FW[key4]=value4
for kkkkkey, vvvvvalue in FW.items():
    print(f"{kkkkkey}: {vvvvvalue}")
# Out:
# Elye Wahi: FW
# Iago Aspas: FW
# Jonathan David: FW
# Loïs Openda: FW
# Folarin Balogun: FW
# Habib Diallo: FW
# Marvin Ducksch: FW
# Miguel Almirón: FW
# Niclas Füllkrug: FW
# Sheraldo Becker: FW
# Thijs Dallinga: FW
# Valentín Castellanos: FW
# Duván Zapata: FW
# Harry Wilson: FW
# Mattia Zaccagni: FW
# Willian: FW
# Felipe Anderson: FW
# Harry Kane: FW
# Junya Ito: FW
# Khvicha Kvaratskhelia: FW
# Jonathan Bamba: FW
